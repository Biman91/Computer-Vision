# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# image gradient is a direction change in the intensity or color in an image
# img = cv2.imread("messi5.jpg", cv2.IMREAD_GRAYSCALE)
img = cv2.imread("sudoku.png", cv2.IMREAD_GRAYSCALE)

lap = cv2.Laplacian(img, cv2.CV_64F, ksize=3) #64F data type
lap = np.uint8(np.absolute(lap)) # convert image

sobelX = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3) # 1 x-direction, 0-y direction
sobelY = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)

sobelX = np.uint8(np.absolute(sobelX))
sobelY = np.uint8(np.absolute(sobelY))

sobelCombined = cv2.bitwise_or(sobelX,sobelY)

titles = ['images', "Laplacian", 'sobelX', 'sobleY' , 'sobelCombined']
images = [img, lap, sobelX, sobelY, sobelCombined]

for i in range(5):
    plt.subplot(2,3,i+1)
    plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
    
plt.show()
